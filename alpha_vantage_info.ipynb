# %%
import requests
import pandas as pd

# %%
url = "https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol=SO&apikey=R9I07X6WRXNI4MPS"
r = requests.get(url)
data = pd.DataFrame.from_dict(r.json()["annualReports"])

# %%
data.T
# Out:
#                                                    0             1  \
# fiscalDateEnding                          2022-12-31    2021-12-31
# reportedCurrency                                 USD           USD
# totalAssets                             134891000000  127534000000
# totalCurrentAssets                       10416000000    8965000000
# cashAndCashEquivalentsAtCarryingValue     1917000000    1798000000
# cashAndShortTermInvestments               1917000000    1798000000
# inventory                                 2677000000    2355000000
# currentNetReceivables                     2067000000    1728000000
# totalNonCurrentAssets                   115858000000  113752000000
# propertyPlantEquipment                   94570000000   91108000000
# accumulatedDepreciationAmortizationPPE   35297000000   34079000000
# intangibleAssets                          5567000000    5725000000
# intangibleAssetsExcludingGoodwill          406000000     445000000
# ...
