# %%
import requests
import pandas as pd

# %%
url = 'https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol=WSM&apikey=R9I07X6WRXNI4MPS'
r = requests.get(url)
data = pd.DataFrame.from_dict(r.json()['annualReports'])

# %%
data.T
# Out:
#                                                  0           1           2  \
# fiscalDateEnding                        2023-01-29  2022-01-30  2021-01-31
# reportedCurrency                               USD         USD         USD
# totalAssets                             4663016000  4625620000  4661424000
# totalCurrentAssets                      2036080000  2323894000  2467080000
# cashAndCashEquivalentsAtCarryingValue    367344000   850338000  1200337000
# cashAndShortTermInvestments              367344000   850338000  1200337000
# inventory                               1456123000  1246372000  1006299000
# currentNetReceivables                    115685000   131683000   143728000
# totalNonCurrentAssets                   2626936000  2301726000  2194344000
# propertyPlantEquipment                  1065381000   920773000   873894000
# accumulatedDepreciationAmortizationPPE  2154009000  2062335000  1953975000
# intangibleAssets                          77307000    85354000    85446000
# intangibleAssetsExcludingGoodwill             None        None        None
# goodwill                                  77307000    85354000    85446000
# investments                                   None        None        None
# longTermInvestments                           None        None        None
# shortTermInvestments                          None        None        None
# otherCurrentAssets                        31967000    26249000    22894000
# otherNonCurrentAssets                    116407000   106250000    87141000
# totalLiabilities                        2961965000  2961413000  3010239000
# totalCurrentLiabilities                 1636451000  1771686000  1848000000
# currentAccountsPayable                   508321000   612512000   542992000
# deferredRevenue                          479229000   447770000   373164000
# currentDebt                                   None        None   299350000
# shortTermDebt                            231965000   217409000   509104000
# totalNonCurrentLiabilities              1354287000  1215685000  1176615000
# capitalLeaseObligations                 1443658000  1284248000  1234811000
# longTermDebt                                  None        None           0
# currentLongTermDebt                           None           0   299350000
# longTermDebtNoncurrent                        None        None           0
# shortLongTermDebtTotal                  1443658000  1284248000  1534161000
# otherCurrentLiabilities                  108138000    94517000    85672000
# otherNonCurrentLiabilities               113821000   106528000   116570000
# totalShareholderEquity                  1701051000  1664207000  1651185000
# treasuryStock                               700000      711000      599000
# retainedEarnings                        1141819000  1074084000  1019762000
# commonStock                                 663000      720000      764000
# commonStockSharesOutstanding              66226000    71982000    76340000
#
#                                                  3           4
# fiscalDateEnding                        2020-02-02  2019-02-03
# reportedCurrency                               USD         USD
# totalAssets                             4054042000  2812844000
# totalCurrentAssets                      1755635000  1694343000
# cashAndCashEquivalentsAtCarryingValue    432162000   338954000
# cashAndShortTermInvestments              432162000   338954000
# inventory                               1100544000  1124992000
# currentNetReceivables                    111737000   107102000
# totalNonCurrentAssets                   2250430000  1074446000
# propertyPlantEquipment                   929038000   929635000
# accumulatedDepreciationAmortizationPPE  1883350000  1812767000
# intangibleAssets                          85343000    85382000
# intangibleAssetsExcludingGoodwill             None        None
# goodwill                                  85343000    85382000
# investments                                   None        None
# longTermInvestments                           None        None
# shortTermInvestments                          None        None
# otherCurrentAssets                        20766000    21939000
# otherNonCurrentAssets                     69666000    59429000
# totalLiabilities                        2818182000  1657130000
# totalCurrentLiabilities                 1609555000  1074812000
# currentAccountsPayable                   521235000   526702000
# deferredRevenue                               None        None
# currentDebt                              527741000        None
# shortTermDebt                            527741000   185020000
# totalNonCurrentLiabilities              1180968000   380944000
# capitalLeaseObligations                 1322502000        None
# longTermDebt                                     0           0
# currentLongTermDebt                      299818000        None
# longTermDebtNoncurrent                        None   299620000
# shortLongTermDebtTotal                  1622320000   299620000
# otherCurrentLiabilities                   73462000    72645000
# otherNonCurrentLiabilities                86389000    81324000
# totalShareholderEquity                  1235860000  1155714000
# treasuryStock                               941000      235000
# retainedEarnings                         644794000   584333000
# commonStock                                 772000      789000
# commonStockSharesOutstanding              77137000    78813000
