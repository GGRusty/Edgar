# %%
import edgar_functions_V2 as edgar

# %%
tickers = [
    "META",
    "AMD",
    "WSM",
    "NVDA",
    "COST",
    "AAPL",
    "TSLA",
    "PLTR",
    "BAC",
    "F",
    "AAL",
    "SQ",
    "AMZN",
    "CCL",
    "SOFI",
    "INTC",
    "XOM",
    "RIVN",
    "MRO",
    "DAL",
    "JPM",
    "TM",
    "DE",
    "UPS",
    "PYPL",
]

# %%
ticker = tickers[0]
annual_df = edgar.process_and_aggregate_annual_data(ticker)
annual_df.T.sort_index(axis=1, ascending=False)
# Out:
# Year                                                               2022  \
# fact
# Period End                                          2022-12-31 00:00:00
# Filing Date                                         2023-02-02 00:00:00
# AccountsPayableAndOtherAccruedLiabilitiesCurrent                    NaN
# AccountsPayableCurrent                                              NaN
# AccountsPayableOtherCurrent                               1,117,000,000
# AccountsPayableTradeCurrent                               4,990,000,000
# AccountsReceivableNetCurrent                             13,466,000,000
# AccruedIncomeTaxesCurrent                                           NaN
# AccruedIncomeTaxesNoncurrent                              6,645,000,000
# AccruedLiabilitiesCurrent                                19,552,000,000
# AccumulatedDepreciationDepletionAndAmortization...                  NaN
# AccumulatedOtherComprehensiveIncomeLossForeignC...       -1,860,000,000
# ...
